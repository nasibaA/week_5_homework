# %% [markdown]
# # Assignment - What's the Weather Like?
#
# ## Background
#
# Whether financial, political, or social -- data's true power lies in its ability to answer questions definitively. So let's take what you've learned about Python requests, APIs, and JSON traversals to answer a fundamental question: "What's the weather like as we approach the equator?"
#
# Now, we know what you may be thinking: _"Duh. It gets hotter..."_
#
# But, if pressed, how would you **provide evidence**?
#
# ## WeatherPy
#
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * OPTIONAL: Include a print log of each city as it's being processed with the city number and city name.
# * OPTIONAL: Save both a CSV of all data retrieved and png images for each scatter plot.
#
# As final considerations:
#
# * You must complete your analysis using a Jupyter notebook.
# * You must use the Matplotlib ,Seaborn or Pandas plotting libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
#
# ## Hints and Considerations
#
# * The city data is generated based on random coordinates; as such, your outputs will not be an exact match to the provided starter notebook.
#
# * You may want to start this assignment by refreshing yourself on the [geographic coordinate system](http://desktop.arcgis.com/en/arcmap/10.3/guide-books/map-projections/about-geographic-coordinate-systems.htm).
#
# * Next, spend the requisite time necessary to study the OpenWeatherMap API. Based on your initial study, you should be able to answer  basic questions about the API: Where do you request the API key? Which Weather API in particular will you need? What URL endpoints does it expect? What JSON structure does it respond with? Before you write a line of code, you should be aiming to have a crystal clear understanding of your intended outcome.
#
# * A starter code for Citipy has been provided. However, if you're craving an extra challenge, push yourself to learn how it works: [citipy Python library](https://pypi.python.org/pypi/citipy).
#
# * Lastly, remember -- this is a challenging activity. Push yourself! If you complete this task, then you can safely say that you've gained a strong mastery of the core foundations of data analytics and it will only go better from here. Good luck!
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Don't modify this cell.
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
#import api_keys
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Don't modify this cell
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 603

# %% [markdown]
# A lot of starter code has been generated for you. Use the cell below to play with the data to ensure you know what's happening.

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city in `cities` using a series of successive API calls. Think: how do you do anything successively?
# * Make sure each city in your dataset includes coordinates, country, max temperature, pressure, humidity and wind speed
# * Use a try-except to handle errors (they will occur)
# * Include a print log of each city as it'sbeing processed (with the city number and city name). City number is just going to count which city is being processed

# %%
city_weather = {"city":[],
                "coordinates":[],
                "country":[],
                "humidity":[],
                "max_temp":[],
                "pressure":[],
                "wind_speed":[],
                "cloudiness":[]}

for city in cities:
    
    base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
    try:   
        req = requests.get(base_url + f'&q={city}')
        json_data = req.json()
        
        
        city_weather["city"].append(json_data["name"])
        city_weather["coordinates"].append(json_data["coord"])
        city_weather["country"].append(json_data["sys"]["country"])
        city_weather["humidity"].append(json_data["main"]["humidity"])
        city_weather["max_temp"].append(json_data["main"]["temp_max"])
        city_weather["pressure"].append(json_data["main"]["pressure"])
        city_weather["wind_speed"].append(json_data["wind"]["speed"])
        city_weather["cloudiness"].append(json_data["clouds"]["all"])
        
        print("processing"+city)
    except:
        print(city+ " not found")
        pass
# Out:
# processingkodiak
# processingcastro
# processingjamestown
# processingqui nhon
# processingelliot
# processingpevek
# processingbengkulu
# taolanaro not found
# mys shmidta not found
# processingcape town
# processingsao miguel do iguacu
# processinginhambane
# processingushuaia
# processingnikolskoye
# processingcoquimbo
# processingport alfred
# processingsitka
# processingbutaritari
# processingspringbok
# processingribeira grande
# processingtorbay
# processingbredasdorp
# attawapiskat not found
# processinghermanus
# processingrikitea
# processingjaruco
# processingkavieng
# processingsamarai
# processingvaini
# processingtiksi
# processingatuona
# illoqqortoormiut not found
# processingnouadhibou
# processingpunta arenas
# processinghobart
# processinghoniara
# processingconselheiro pena
# processingcherskiy
# processingsaint george
# processingboysun
# saleaula not found
# processingavarua
# processingboguchany
# processingcabo san lucas
# processingmalko tarnovo
# processingkamenka
# processingnew norfolk
# processingbethel
# processingmethven
# processingdarhan
# processingkavaratti
# saint-henri-de-levis not found
# processinglebu
# processingtuktoyaktuk
# processingqaanaaq
# processingvao
# processingmataura
# processingpuerto ayora
# processingvanimo
# processingbonthe
# processingsaskylakh
# processinghithadhoo
# processingsaint anthony
# processingkhatanga
# processingfaanui
# processingkutum
# processingbarrow
# processingsal rei
# belushya guba not found
# processinggeorgetown
# processinggalesong
# processingpauini
# processingenumclaw
# processingmar del plata
# processingte anau
# processingfaya
# processingponta do sol
# processingtasiilaq
# processingunity
# processinghilo
# processingacarau
# processingkapaa
# processingriyadh
# processingzhanaozen
# processingyumen
# yanan not found
# processingcarnarvon
# processingjuneau
# processingupernavik
# khonuu not found
# processingmoerai
# processingpaamiut
# processingmastic beach
# processingalbany
# processinghavre-saint-pierre
# processingport augusta
# processingcoihaique
# processingnanning
# processingfortuna
# processingvardo
# processingvila franca do campo
# processingmahebourg
# processingbeihai
# processingbusselton
# processingkeetmanshoop
# processingacajutla
# processingtieli
# processingbakel
# processingyellowknife
# processingchapeco
# processingqasigiannguit
# sentyabrskiy not found
# processingpayo
# processingcomodoro rivadavia
# processingsanta cruz
# processingchicama
# processingnanortalik
# processingclarence town
# processingportland
# processingzhezkazgan
# processingsao gabriel da cachoeira
# processingsao paulo de olivenca
# processingmount gambier
# processingchacabuco
# processingsamfya
# processingguerrero negro
# processingalpena
# processingprovideniya
# processingsorland
# processingtarko-sale
# processingluau
# processingbow island
# processingminsk
# processingverkhnyaya inta
# processingluderitz
# vaitupu not found
# processingfinote selam
# processingeast london
# processingsaint-pierre
# processingpoum
# processingtouros
# processingairai
# processingkatsuura
# barentsburg not found
# processingbrae
# processingsan patricio
# processingaldan
# processingsao filipe
# processingnecochea
# processingvangaindrano
# processingavera
# novoilinskiy not found
# processingnome
# processingpetauke
# processingotane
# processingbandarbeyla
# processingareia branca
# processingankang
# processinghualmay
# itahari not found
# processingchuy
# hendijan not found
# processingyar-sale
# processingsorokino
# processinghonningsvag
# processingostrovnoy
# processingzigong
# processingbatemans bay
# processingbathsheba
# processingcelestun
# processingyabrud
# processingthompson
# processingwahiawa
# galgani not found
# processinglorengau
# processinglaureles
# processingflagstaff
# processingsemporna
# processinghammerfest
# processingnarsaq
# processingshimoda
# processingvictoria
# processingdikson
# amderma not found
# processingvila velha
# processingconstitucion
# processingpadang
# processinghusavik
# processingel tigre
# processinginnisfail
# tsihombe not found
# processingisangel
# processingchokurdakh
# processingariquemes
# processingkota tinggi
# processingjombang
# processingbahia blanca
# processingmuros
# processingserik
# processingseverobaykalsk
# processingchumikan
# processingtawau
# louisbourg not found
# processinghofn
# processingsarany
# processingsalina cruz
# processingarzgir
# processingpangnirtung
# processinglongyearbyen
# processingtuy hoa
# processinggoure
# processinganloga
# processingarraial do cabo
# processingkalmar
# litoral del san juan not found
# processingkahului
# processingkaitangata
# processingbambous virieux
# processingoranjemund
# processingsaint-philippe
# samusu not found
# processingkuah
# processingdeoband
# processingport lincoln
# processingumm bab
# processingelizabethtown
# processingbenguela
# skiros not found
# processingbairnsdale
# processingiqaluit
# processingnovopokrovka
# processingstornoway
# processingsan carlos de bariloche
# processingleningradskiy
# processingdondo
# processingballina
# processingnohar
# processingbluff
# processingjawhar
# bandar-e torkaman not found
# processingklaksvik
# processingarua
# processingdongsheng
# santa eulalia del rio not found
# processingsao joao da barra
# processingdeputatskiy
# processingsan ramon
# processingsan vicente
# processingbayburt
# processingsevero-kurilsk
# processingmecca
# processingyarada
# processingfare
# processingport elizabeth
# processingudachnyy
# processingsvetlogorsk
# processingjardim
# processinglagoa
# port-de-paix not found
# processingponta delgada
# processinghuilong
# processingyeniseysk
# processingizvestkovyy
# processingsimbahan
# processingancud
# processingpanama city
# processingbandar-e lengeh
# processingsampit
# processingsalalah
# processingambovombe
# processinggrand-lahou
# processingsarkand
# burica not found
# processingcascais
# processingnamatanai
# processinggrindavik
# processingsao sebastiao
# ambodifototra not found
# processingpurpe
# processingsur
# processingcaborca
# processingkichmengskiy gorodok
# processingous
# rawannawi not found
# processingclyde river
# processingzeya
# processingwitbank
# processingbujumbura
# processingpoyarkovo
# processingpuro
# processingalofi
# processingkabo
# processingilulissat
# processingbhawanipatna
# processingsao jose da coroa grande
# processingcarpentras
# processingormond beach
# processingmakakilo city
# processingwest bay
# processingvila
# processinghalf moon bay
# processingketchikan
# processingminab
# processingcollege
# processingagadez
# processinglagunillas
# processingsanta teresa
# processingtautira
# processingsmithers
# processingwanning
# bargal not found
# processingawbari
# processingulaangom
# processingbilibino
# processingaykhal
# processingnamibe
# aflu not found
# processingkalangala
# processingparana
# processingbirjand
# processingiwamizawa
# processinggamovo
# processingmareeba
# processingcap-aux-meules
# processingbeyneu
# grande-riviere not found
# processingcidreira
# processingsirjan
# processingsouillac
# processingrayadrug
# karauzyak not found
# processingsan ignacio
# processinghambantota
# processingtessalit
# processingkrasnooktyabrskiy
# processingcarupano
# processingmatane
# processingnovikovo
# processingmalanje
# processingnaliya
# processingbeloha
# processingekhabi
# processinghasaki
# processingesperance
# processingvagay
# processingaljezur
# processingroma
# processingkomsomolskiy
# processinghervey bay
# processingalbanel
# processingnorman wells
# processingdumas
# kesennuma not found
# processingkhandyga
# processingantofagasta
# processingsrednekolymsk
# processinghouma
# processingtalnakh
# processingpacific grove
# processingkidal
# processingsurt
# processingarona
# processingzhigansk
# processingmoose jaw
# processingokhotsk
# processingolafsvik
# processingust-kan
# processingkerema
# processingsaldanha
# processingtodos santos
# processingathens
# processingbelmonte
# bolonchen not found
# processingmosquera
# processingpayson
# processingwhitianga
# processingverkhnevilyuysk
# processingruwi
# processingimbituba
# processinghobyo
# processingsanto antonio do ica
# processingpisco
# processingtupik
# processingdurham
# processingbartica
# processingcodrington
# processingboffa
# processingsisimiut
# processingpoya
# processingarandis
# processingacari
# processingkaputa
# processinglos llanos de aridane
# processingcerrito
# processingluanda
# processingport hedland
# processingcharters towers
# processingmaloy
# processingtakoradi
# processingitarema
# processingpuerto del rosario
# processingnuuk
# processinglucea
# processingboromo
# jiddah not found
# processinglaguna
# processingmarystown
# processingbalykshi
# processinglatung
# processingcao bang
# processingsibolga
# processingmoosomin
# processingchagoda
# processingnaze
# processingkemalpasa
# processingbanda aceh
# processingansonia
# kachikau not found
# processingseoul
# processingtambura
# processinganshun
# processinggazanjyk
# processingvostok
# grand river south east not found
# processingharnosand
# processingboa vista
# processingseinajoki
# processingnanlong
# processingloten
# processingporto novo
# processingsemarang
# processingviana
# processingmingshui
# processingcalama
# processingban nahin
# processingusinsk
# processingkoubia
# kamenskoye not found
# processingvera cruz
# processingyankton
# processingluwuk
# processingtiznit
# processingsalaverry
# processingberlevag
# processingsalinas
# processingtaft
# processingsaint-augustin
# processingrobertsport
# processingfreeport
# processinglere
# processingishigaki
# processingfairbanks
# processingbyron bay
# processingmatamoros
# processingtrinidad
# processingkimbe
# processinghirara
# processingtopolobampo
# purace not found
# processinggamba
# processingandrews
# processingcoronado
# sorvag not found
# processingdivnoye
# processingsinnar
# processingbatagay
# processingmaracai
# processingsantiago
# processingeureka
# processingmoose factory
# processingquchan
# processingkyra
# processingatar
# processingafsin
# processinglabuhan
# processingpinawa
# processingcortez
# processingabu dhabi
# processingberingovskiy
# processingahipara
# processingcareiro da varzea
# processingtezu
# processingavallon
# processinglata
# lolua not found
# processingkarpogory
# processingamapa
# processingraudeberg
# processingbiri
# processingbuluang
# processingbuta
# processingrossland
# processingbumbuna
# processingmnogovershinnyy
# processingmontrose
# processingsoloneshnoye
# nguiu not found
# processingkingaroy
# processingtalaya
# processinglompoc
# processingmiraflores
# processingsevernyy
# processingphan thiet
# processingharper
# processingrio grande
# processingkhorramshahr
# processingtuatapere
# processingpraia
# processingcristalina
# processingwaingapu
# processingbereznehuvate
# processingtateyama
# processingkendari
# processingrawson
# processingsuoyarvi
# processingfort nelson
# processingsumbawanga
# processingsi sa ket
# processingbarcelos
# processingbetsiamites
# processingkhor
# bengkalis not found
# processingbubaque
# processingmesa
# processingbitkine
# mrirt not found
# processingtupelo
# processingmarawi
# processingtumut
# processingmakinsk
# processingcoahuayana
# processingmoosburg
# processingturochak
# processingalbert town
# processingransang
# processingcaravelas
# angra not found
# processingwajir
# processingsenanga
# processingport blair
# processingsioux lookout
# processingsola
# fevralsk not found
# processinghamilton
# processinggigmoto
# processingbirao
# processingtorrelavega
# processingtecpan
# processingmindelo
# processingewa beach
# processingviedma
# processingkirillov
# processingiturama
# processingzhangye
# processingport hardy
# processingarawa
# processingsenno
# processingkamiiso
# processingtsumeb
# processingcamacha
# processingkinablangan
# processingkrasnoselkup
# processingsaint-paul
# processinghenties bay
# processingalpatovo
# processingnautla
# processingpetropavlovsk-kamchatskiy
# processingacapulco
# processingazamgarh
# processingcayenne
# processingkano
# processingsena madureira
# processingsoma
# grand centre not found
# processingyulara
# processingsanta cruz del sur
# processingmaues
# processingesso
# processingyavoriv
# processingbaykit
# processingkodino
# guelengdeng not found
# processingrockport
# processinghavoysund
# processingmaniitsoq
# processinggat
# processingtalbahat
# processingbuin
# kegayli not found
# processingwalvis bay
# processinggeraldton
# processingrostovka
# processingchristchurch
# marcona not found
# processingshache
# processingkushima
# processingkamarion
# processinghokitika
# processingkropotkin
# processingkindersley
# processingotsuki
# processingheihe
# nizhneyansk not found

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Display the DataFrame
# * Export the city data into a .csv. Open it up in excel or another program to make sure it looks as expected

# %%
weather_df = pd.DataFrame.from_dict(city_weather)
weather_df
lat_lon_df = pd.DataFrame(weather_df["coordinates"].values.tolist(), index=weather_df.index)
df = pd.merge(weather_df, lat_lon_df, left_index=True, right_index=True)
df
df.to_csv("city_weather_2.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Use matplotlib
# * Save the plotted figures as .pngs and embed those pngs in your readme file.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#df = pd.read_csv("city_weather_2.csv")
fig, ax = plt.subplots()
plt.style.use("ggplot")
ax.scatter( x = df["lat"],y = df["max_temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.title("City Latitude vs. Max Temperature(10/23/2021)")
fig.savefig("City_lat_temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
plt.style.use("default")
ax.scatter( x = df["lat"],y = df["humidity"],color ="c")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.title("City Latitude vs. Humidity(10/23/2021)")
fig.savefig("city_lat_hum.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
plt.style.use("bmh")
ax.scatter(x = df["lat"],y = df["cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title("City Latitude vs.Cloudiness(10/23/2021)")
fig.savefig("city_lat_cl.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
ax.scatter(x = df["lat"],y = df["wind_speed"])
plt.xlabel("Latitude")
plt.ylabel("wind Speed (mph)")
plt.title("City Latitude vs.Wind Speed(10/23/2021)")
fig.savefig("city_lat_ws.png")
plt.show()

# %% [markdown]
# ### Use the Seaborn library to re-create 2-4 of the above plots.
# * Use the same data just make a different plot.
# * Note the differences in amount of code required to generate a similar plot.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x = "lat",y = "cloudiness",
                data = df,
               marker="D").set(title ="City Latitude vs.Cloudiness(10/23/2021)",
                                xlabel = "Latitude",ylabel ="Cloudiness")
plt.savefig("sb_lat_cl.png")
plt.show()

# %%
sns.relplot(x= "lat",y = "wind_speed",
           data = df,
            kind = "scatter",
            s=150,
            color="red",
           marker="8",).set(title = "City Latitude vs.Wind Speed(10/23/2021)",
                                 xlabel= "Latitude",
                                 ylabel = "wind Speed (mgh)")
plt.savefig("sb_lat_ws.png")

plt.show()

# %% [markdown]
# ### As a Data-Scientist:
# In addition to generating data, munging data and plotting data you will also be responsible for *interpreting* data.
# * Provide a written description of three observable trends based on the data.

# %%
# 1.Temperature tends to drop as we move away from 0 Latitude.
# 2. All cities near 0 Latitude have 60+ humidity.
# 3. Very few cities have wind speed higher than 20 mph.

# %% [markdown]
# # Seaborn

# %% [markdown]
# ![seaborn.PNG](attachment:seaborn.PNG)

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ![matplotlib.PNG](attachment:matplotlib.PNG)

# %% [markdown]
# ### OPTIONAL Homework Problem:
# * Use a **different** api endpoint such as `Hourly Forecast 4 days` to get data.
# * Other weather api endpoints are documented [here](https://openweathermap.org/api).
# * You will have to change the URL parameters to get the data you want.
# * Get the data into a data structure of your choice. (Pandas, dicts, lists etc...)
# * Use the plotting library of your choice to make 1-4 plots of your choice.
