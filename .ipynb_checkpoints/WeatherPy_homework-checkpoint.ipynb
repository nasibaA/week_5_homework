# %% [markdown]
# # Assignment - What's the Weather Like?
#
# ## Background
#
# Whether financial, political, or social -- data's true power lies in its ability to answer questions definitively. So let's take what you've learned about Python requests, APIs, and JSON traversals to answer a fundamental question: "What's the weather like as we approach the equator?"
#
# Now, we know what you may be thinking: _"Duh. It gets hotter..."_
#
# But, if pressed, how would you **provide evidence**?
#
# ## WeatherPy
#
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * OPTIONAL: Include a print log of each city as it's being processed with the city number and city name.
# * OPTIONAL: Save both a CSV of all data retrieved and png images for each scatter plot.
#
# As final considerations:
#
# * You must complete your analysis using a Jupyter notebook.
# * You must use the Matplotlib ,Seaborn or Pandas plotting libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
#
# ## Hints and Considerations
#
# * The city data is generated based on random coordinates; as such, your outputs will not be an exact match to the provided starter notebook.
#
# * You may want to start this assignment by refreshing yourself on the [geographic coordinate system](http://desktop.arcgis.com/en/arcmap/10.3/guide-books/map-projections/about-geographic-coordinate-systems.htm).
#
# * Next, spend the requisite time necessary to study the OpenWeatherMap API. Based on your initial study, you should be able to answer  basic questions about the API: Where do you request the API key? Which Weather API in particular will you need? What URL endpoints does it expect? What JSON structure does it respond with? Before you write a line of code, you should be aiming to have a crystal clear understanding of your intended outcome.
#
# * A starter code for Citipy has been provided. However, if you're craving an extra challenge, push yourself to learn how it works: [citipy Python library](https://pypi.python.org/pypi/citipy).
#
# * Lastly, remember -- this is a challenging activity. Push yourself! If you complete this task, then you can safely say that you've gained a strong mastery of the core foundations of data analytics and it will only go better from here. Good luck!
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Don't modify this cell.
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
#import api_keys
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Don't modify this cell
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 636

# %% [markdown]
# A lot of starter code has been generated for you. Use the cell below to play with the data to ensure you know what's happening.

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city in `cities` using a series of successive API calls. Think: how do you do anything successively?
# * Make sure each city in your dataset includes coordinates, country, max temperature, pressure, humidity and wind speed
# * Use a try-except to handle errors (they will occur)
# * Include a print log of each city as it'sbeing processed (with the city number and city name). City number is just going to count which city is being processed

# %%
city_weather = {"city":[],
                "coordinates":[],
                "country":[],
                "humidity":[],
                "max_temp":[],
                "pressure":[],
                "wind_speed":[],
                "cloudiness":[]}

for city in cities:
    
    base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
    try:   
        req = requests.get(base_url + f'&q={city}')
        json_data = req.json()
        
        
        city_weather["city"].append(json_data["name"])
        city_weather["coordinates"].append(json_data["coord"])
        city_weather["country"].append(json_data["sys"]["country"])
        city_weather["humidity"].append(json_data["main"]["humidity"])
        city_weather["max_temp"].append(json_data["main"]["temp_max"])
        city_weather["pressure"].append(json_data["main"]["pressure"])
        city_weather["wind_speed"].append(json_data["wind"]["speed"])
        city_weather["cloudiness"].append(json_data["clouds"]["all"])
        
        print("processing"+city)
    except:
        print(city+ " not found")
        pass
# Out:
# processingsaint anthony
# processingjuneau
# processingpunta arenas
# processinghoniara
# processingarraial do cabo
# processingsaskylakh
# processingsouth venice
# processingibanda
# processingumm lajj
# processingroald
# processingacajutla
# processinglaki
# processingvilla de san francisco
# processinghilo
# processingwilmington
# processinglowestoft
# processingatar
# processingchoya
# processingmataura
# processingdikson
# processingrikitea
# processingalbany
# processingkhatanga
# sentyabrskiy not found
# processinghavelock
# processingchirongui
# processingvaini
# processinganaconda
# processingushuaia
# processingkirakira
# processingatuona
# processinggurlan
# processingponta do sol
# processingnadym
# attawapiskat not found
# processingbredasdorp
# processingaxim
# processingmar del plata
# processingostrovnoy
# processingnikolskoye
# processingkaitangata
# illoqqortoormiut not found
# processingshemursha
# processingabai
# processingmiranda
# processingupernavik
# processingcaucaia
# processingnaigarhi
# processinghobart
# processingaklavik
# processingsaint-francois
# tokzar not found
# processingkodiak
# processingbilibino
# processingavarua
# processingnemuro
# processingtabuk
# processingvictoria
# processingalamosa
# processingport alfred
# processingegvekinot
# processingnew norfolk
# processingnorman wells
# processingvilhena
# processinglodja
# taolanaro not found
# processingchokurdakh
# processingprovideniya
# processingangra dos reis
# processinghermanus
# processingporbandar
# processingambilobe
# processingcalvinia
# processingpevek
# processingtaoudenni
# processingpuerto leguizamo
# mys shmidta not found
# processingsarbogard
# processingballina
# processingsaint-philippe
# processingcastro
# processingbarrow
# processinghambantota
# processinggrindavik
# processingnagato
# processingtasiilaq
# processinggigmoto
# processingsaint-augustin
# barentsburg not found
# processingpuerto ayora
# processingbambanglipuro
# processingbambous virieux
# processingcravo norte
# processingbagotville
# processingbathsheba
# processingkosh-agach
# processingostersund
# processingbluff
# processingshenjiamen
# processingshimoda
# processingkapaa
# processingsimao
# processingtiksi
# processingauki
# processingtuscaloosa
# processingtondon
# processingcodrington
# processingbengkulu
# processingport lincoln
# processingcap malheureux
# processingkongoussi
# processingsoyo
# processingfaanui
# saryshagan not found
# processingbusselton
# processingzyryanskoye
# processingmandera
# processingaiquile
# processingvila velha
# processingmercedes
# processingairai
# processingpetropavlovsk-kamchatskiy
# processinghithadhoo
# processingsindor
# processingbutaritari
# processingvagur
# processingdwarka
# processingfortuna
# processinglixourion
# processingfonte boa
# processingkitami
# processingsabha
# processingkysyl-syr
# processingconstitucion
# processingvostok
# processingsambava
# processinglazaro cardenas
# saleaula not found
# processingbisauli
# processingnaze
# processingoster
# processingsaldanha
# processinglavrentiya
# processingstolin
# processingnome
# processingcabo san lucas
# processingamboasary
# processingtegal
# processingshakhtinsk
# processingtuktoyaktuk
# processinghede
# processingheze
# processingeast london
# processingcape town
# processingbinzhou
# processingahuimanu
# processinglebu
# processingbonthe
# processingkailua
# processingbaglan
# processinggeorgetown
# processingchivilcoy
# processingmarawi
# processingjamestown
# processingambon
# processingtatawin
# processingclyde river
# processingyellowknife
# processingeureka
# processingalong
# processingbarra da estiva
# processingesperance
# processingcomodoro rivadavia
# processingsaint george
# processingust-barguzin
# processingtingi
# amderma not found
# processingvrangel
# processinglongyearbyen
# processingport elizabeth
# processingkieta
# processingporto tolle
# processingkatobu
# kamenskoye not found
# processinghenties bay
# processingagirish
# karaul not found
# processingqaanaaq
# processingchara
# processingtuban
# belushya guba not found
# processinggeraldton
# processingbardiyah
# processingixtapa
# processingprince rupert
# processinglagoa
# processingplover
# processingngunguru
# processinglorengau
# processingkruisfontein
# processinghasaki
# processingbianzhuang
# processingsanta cruz
# processingdjibo
# processingcamacha
# processingsao filipe
# processingpietarsaari
# processingwaipawa
# jinchengjiang not found
# grand river south east not found
# processingkonevo
# processingsan cristobal
# processingsalalah
# processingmehran
# processingbethel
# processinggeorge town
# processingnanortalik
# processingtucuman
# processingsarkand
# tsihombe not found
# processingmahebourg
# processinglompoc
# processingwattegama
# processingnyandoma
# processingsalinas
# processingsnezhnogorsk
# processingsosnovo-ozerskoye
# processingigarka
# processingambulu
# processingcherskiy
# processingfaya
# processinghalifax
# processingmutare
# processingagadir
# processingsevero-kurilsk
# processingwhitianga
# processinggreen valley
# processingsept-iles
# processingnishihara
# processingsobolevo
# processingtezu
# processingvestmannaeyjar
# processingribeira grande
# processingharper
# processingthompson
# processingbelgrade
# processingkavieng
# processingnelson bay
# processingtabou
# processingtrincomalee
# processinghami
# processingrussell
# processingathens
# processingvanimo
# processinghomer
# processingust-nera
# processingsanta barbara
# processingchalus
# processingsouillac
# paradwip not found
# processingroebourne
# processingwanning
# processingfairbanks
# processingsterling
# processingconceicao do araguaia
# processingsergeyevka
# processingriyadh
# processingthe valley
# processingbocas del toro
# processingla paz
# processingkiunga
# processingnajran
# processingrio grande
# processingshafranovo
# processingpotsdam
# processingsan antonio
# processingnakamura
# processinghobyo
# processingkavaratti
# processingadrar
# processingcarnarvon
# processinggorontalo
# processinggoiania
# processinganadyr
# processingtalnakh
# processingbeloha
# processingnamibe
# coulihaut not found
# processingbandarbeyla
# processingchuy
# processingyatou
# processingturayf
# processingkampong chhnang
# processingdabat
# processingspringbok
# processingkomsomolskiy
# processingpuerto ayacucho
# processingcamalu
# processinglumphat
# processinglagdo
# processingisabela
# processingawjilah
# processingtura
# processingkupang
# processingkampot
# processingboca do acre
# processinghouma
# processingkidal
# processingmarzuq
# processingnouakchott
# processingfevik
# processingbroome
# processingnieves
# processingsioux lookout
# processingasfi
# processinglos llanos de aridane
# processingsananduva
# processingrehoboth
# processingalofi
# processingvardo
# processinglakatoro
# processingkalabo
# palabuhanratu not found
# processingmarienburg
# processingpalauig
# processingsandovo
# processingsan andres
# processingpalaikastron
# processingfalmouth
# processingplouzane
# processingpresidencia roque saenz pena
# processingkhilok
# processingjejuri
# processingodienne
# processingpalmas
# processingmagistralnyy
# processingberingovskiy
# processingdingle
# processingnecochea
# processingmashhad
# processingaktash
# mocambique not found
# processingabu dhabi
# processingguerrero negro
# marv dasht not found
# processinglima
# processingpiney green
# processinginirida
# processingmount pleasant
# processingilulissat
# processinghollola
# processingbonavista
# processingpaita
# processingastoria
# processingfare
# processingscranton
# processingrocky mountain house
# processingtigzirt
# processingmuravlenko
# processingjingdezhen
# processingklaksvik
# processingtorbay
# processingte anau
# processingnorth battleford
# processingfort nelson
# processingtessalit
# processingsaint-pierre
# processingdutse
# processingtwin falls
# processingkarratha
# processingcabra
# processingbara
# processingturinsk
# marcona not found
# processingparintins
# processingguaymas
# processingburibay
# processingqinzhou
# wahran not found
# processingqitaihe
# processinggrants pass
# processingbontang
# aflu not found
# processingport-cartier
# processingpoum
# processingkudahuvadhoo
# processinghwange
# processingbelaya gora
# processinggobo
# processingsivaki
# processingsan quintin
# processingavera
# processingalexandria
# processingnatchitoches
# processingyoukounkoun
# processingberlevag
# tumannyy not found
# processingsrednekolymsk
# processinghongjiang
# processingamla
# processingsakakah
# processingthunder bay
# processingseoul
# processingalice springs
# processingmyitkyina
# processingshelburne
# processingkrasnoselkup
# processingaraouane
# processingimbituba
# processingsorong
# processingrockland
# processingluderitz
# processinglaguna
# processinghaysville
# processingmecca
# processingnuevo progreso
# processingerie
# processingcidreira
# processingmobaye
# processingnarasannapeta
# taburi not found
# processingullapool
# processingpundaguitan
# sug-aksy not found
# processingpacific grove
# processingmafeteng
# processingport blair
# processingnouadhibou
# processingwestport
# processinguyuni
# processingmulege
# ambodifototra not found
# processingmaniitsoq
# processingpaamiut
# processingananas
# processingstaraya vichuga
# processingtecoanapa
# processinghualmay
# processingthomaston
# processingsanta maria
# processingmezimesti
# processingkizhinga
# processingchicama
# processingmoranbah
# umm ruwabah not found
# processingarcos
# processingusinsk
# processingnanakuli
# processingbozhou
# processinghaines junction
# vaitupu not found
# processingvao
# processingvila
# processingvoiron
# jujuy not found
# processingport augusta
# processingnautla
# processingiskateley
# processingsalta
# bandar-e torkaman not found
# processingpadang
# processingaltamont
# processingmendoza
# processingmareeba
# processinghegang
# processingilhabela
# andevoranto not found
# processingsaint-louis
# processingcaravelas
# processingvaitape
# processingla tuque
# processinghastings
# processinglata
# processinggriffith
# processingkikwit
# processinggornoye loo
# processingsheridan
# uroteppa not found
# processingturinskaya sloboda
# processingdunedin
# processingkatsuura
# processingyamada
# processingwaingapu
# processingscarborough
# processingmoerai
# processingnhulunbuy
# processingmarialva
# processinghervey bay
# processingkamenka
# processingredmond
# processingisangel
# processingasau
# processingindramayu
# processingrawson
# nizhneyansk not found
# processingsibu
# stoyba not found
# processingyanam
# processingmanokwari
# processingvereshchagino
# processingsofia
# processingvuktyl
# processingnortham
# processingfiladelfia
# processingmale
# processingmandurah
# processingkinablangan
# processingcienfuegos
# processingsur
# processingcross lanes
# processingfuling
# processingbeinamar
# processingtuatapere
# processingsabang
# processingmeadow lake
# processingnuevitas
# processingnamie
# processingpowell river
# processingratne
# processinglucea
# burica not found
# processingmargate
# processingfriockheim
# processingcayambe
# processingescarcega
# processinglagoa santa
# processingmount gambier
# processingleh
# processingbrae
# processingumm kaddadah
# processingmakarov
# processingokhotsk
# processingsevero-yeniseyskiy
# processingtaksimo
# processingpangnirtung
# processingeirunepe
# processingsandpoint
# processingpedro carbo
# processingahipara
# processingyangambi
# processingiquique
# processingyerbogachen
# processingflinders
# processingcockburn town
# processingmanubul
# processingverkhnetulomskiy
# processingtouros
# processingfrankfort
# processingbuala
# processingratzeburg
# processingalibag
# processingla ronge
# processingxai-xai
# processingabbeville
# processingsoma
# processingjabinyanah
# processingbasco
# processingmapiripan
# umzimvubu not found
# processingedd
# processingkaberamaido
# louisbourg not found
# processingnelas
# processinglerwick
# processingporto santo
# processingsao joao da barra
# processingcoihaique
# processingrusskiy
# processingmporokoso
# processingchake chake
# processingsafut
# processingchimbarongo
# processinghauterive
# processingsinegorskiy
# scottsburgh not found
# processingrichards bay
# processingshizunai
# processingnarsaq
# processingarona
# processingbosaso
# processingileza
# processingtoamasina
# processingrio blanco
# processingmorgan city
# processingmaksatikha
# processinghofn
# processingsan rafael
# grand centre not found
# processingtulagi
# processingmaryville
# processingerenhot
# processinglichinga
# processingucluelet
# processinglure
# processinglangub
# processinglyubashivka
# processingcoari
# processingkununurra
# processingmbulu
# processinghandan
# processingnizwa
# lolua not found
# sumbawa not found
# processingvictor harbor
# processingroad town
# processinghailar
# processingdublyany
# processinggjovik
# processingjoensuu
# processingbela
# processingiwanai
# processingbaykit
# processingkedougou
# processingajaccio
# processingmakakilo city
# kleck not found
# processingpisco
# processingiqaluit
# processingyatsuo
# processingmeiganga
# processingakdagmadeni
# processingdalian
# processingsemme
# processingspearfish
# processingmayumba
# processingambatondrazaka
# processingaquidauana
# processingkismayo
# processingnortelandia
# mutsamudu not found
# warqla not found
# processingtocopilla
# processingshakawe
# processingstornoway
# processingmladenovac
# processingmuros

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Display the DataFrame
# * Export the city data into a .csv. Open it up in excel or another program to make sure it looks as expected

# %%
weather_df = pd.DataFrame.from_dict(city_weather)
weather_df
lat_lon_df = pd.DataFrame(weather_df["coordinates"].values.tolist(), index=weather_df.index)
df = pd.merge(weather_df, lat_lon_df, left_index=True, right_index=True)
df
df.to_csv("city_weather_2.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Use matplotlib
# * Save the plotted figures as .pngs and embed those pngs in your readme file.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#df = pd.read_csv("city_weather_2.csv")
fig, ax = plt.subplots()
plt.style.use("ggplot")
ax.scatter( x = df["lat"],y = df["max_temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(F)")
plt.title("City Latitude vs. Max Temperature(10/23/2021)")
fig.savefig("City latitude vs. Max Temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
plt.style.use("default")
ax.scatter( x = df["lat"],y = df["humidity"],color ="c")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.title("City Latitude vs. Humidity(10/23/2021)")
fig.savefig("City Latitude vs.Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
plt.style.use("bmh")
ax.scatter(x = df["lat"],y = df["cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title("City Latitude vs.Cloudiness(10/23/2021)")
fig.savefig("City Latitude vs. Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
ax.scatter(x = df["lat"],y = df["wind_speed"])
plt.xlabel("Latitude")
plt.ylabel("wind Speed (mph)")
plt.title("City Latitude vs.Wind Speed(10/23/2021)")
fig.savefig("City Latitude vs. Wind Speed.png")
plt.show()

# %% [markdown]
# ### Use the Seaborn library to re-create 2-4 of the above plots.
# * Use the same data just make a different plot.
# * Note the differences in amount of code required to generate a similar plot.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x = "lat",y = "cloudiness",
                data = df,
               marker="D").set(title ="City Latitude vs.Cloudiness(10/23/2021)",
                                xlabel = "Latitude",ylabel ="Cloudiness")
plt.savefig("Seaborn - City Latitude vs. Cloudiness.png")
plt.show()

# %%
sns.relplot(x= "lat",y = "wind_speed",
           data = df,
            kind = "scatter",
            s=150,
            color="red",
           marker="8",).set(title = "City Latitude vs.Wind Speed(10/23/2021)",
                                 xlabel= "Latitude",
                                 ylabel = "wind Speed (mgh)")
plt.savefig("Seaborn - City Latitude vs.Wind Speed.png")

plt.show()

# %% [markdown]
# ### As a Data-Scientist:
# In addition to generating data, munging data and plotting data you will also be responsible for *interpreting* data.
# * Provide a written description of three observable trends based on the data.

# %%
# 1.Temperature tends to drop as we move away from 0 Latitude.
# 2. All cities near 0 Latitude have 60+ humidity.
# 3. Very few cities have wind speed higher than 20 mph.

# %% [markdown]
# # Seaborn

# %% [markdown]
# ![seaborn.PNG](attachment:seaborn.PNG)

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ![matplotlib.PNG](attachment:matplotlib.PNG)

# %% [markdown]
# ### OPTIONAL Homework Problem:
# * Use a **different** api endpoint such as `Hourly Forecast 4 days` to get data.
# * Other weather api endpoints are documented [here](https://openweathermap.org/api).
# * You will have to change the URL parameters to get the data you want.
# * Get the data into a data structure of your choice. (Pandas, dicts, lists etc...)
# * Use the plotting library of your choice to make 1-4 plots of your choice.
